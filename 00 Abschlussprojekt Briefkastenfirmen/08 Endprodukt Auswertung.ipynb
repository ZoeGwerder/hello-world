# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import time
import pandas as pd
from bs4 import BeautifulSoup
from tqdm import tqdm
import os
import re
folderpath=r"C:\Users\Zoe\Desktop\maz-datenjournalismus\Daten_BR_Handelsreg"

# %%
df_sauber=pd.read_csv(folderpath+"/BRFrames/Stadt_Zug_sauber")

# %%
dfhr=df_sauber[["Adresse", "Anzahl", "GDENAME"]]
dfhr_f=dfhr[dfhr["Anzahl"]>100]

# %%
dfhr_f.sort_values("Anzahl", ascending=False)
# Out:
#                        Adresse  Anzahl GDENAME
# 4219    Bahnhofstrasse 21, Zug     328     Zug
# 4173     Baarerstrasse 75, Zug     277     Zug
# 4682    Chamerstrasse 172, Zug     220     Zug
# 157        Dammstrasse 19, Zug     219     Zug
# 1435  Industriestrasse 47, Zug     197     Zug
# 4205    Bahnhofstrasse 10, Zug     193     Zug
# 4113    Baarerstrasse 137, Zug     161     Zug
# 3779     Baarerstrasse 10, Zug     156     Zug
# 4058         Bahnhofplatz, Zug     155     Zug
# 3989   Baarerstrasse 11.2, Zug     152     Zug
# 4078    Baarerstrasse 112, Zug     152     Zug
# 725       Gubelstrasse 11, Zug     149     Zug
# 4217    Bahnhofstrasse 20, Zug     148     Zug
# 4176     Baarerstrasse 78, Zug     144     Zug
# 2335       Poststrasse 30, Zug     140     Zug
# 4180     Baarerstrasse 82, Zug     139     Zug
# 681   Grienbachstrasse 11, Zug     133     Zug
# 4187     Baarerstrasse 95, Zug     130     Zug
# 600    Gotthardstrasse 26, Zug     128     Zug
# 4221    Bahnhofstrasse 23, Zug     126     Zug
# 4147     Baarerstrasse 43, Zug     122     Zug
# 2325       Poststrasse 14, Zug     121     Zug
# 602    Gotthardstrasse 28, Zug     119     Zug
# 4561      Alpenstrasse 15, Zug     119     Zug
# 4177     Baarerstrasse 79, Zug     118     Zug
# 2332       Poststrasse 24, Zug     118     Zug
# 4225    Bahnhofstrasse 28, Zug     106     Zug
# 4159     Baarerstrasse 53, Zug     104     Zug
# 4116     Baarerstrasse 14, Zug     103     Zug
# 4162     Baarerstrasse 57, Zug     103     Zug
